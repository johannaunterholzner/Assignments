# %% [markdown]
# ## Second Assignment

# %% [markdown]
# #### 1) Create a function called **"even_squared"** that receives an integer value **N**, and returns a list containing, in ascending order, the square of each of the even values, from 1 to N, including N if applicable.

# %%
def even_squared():
    N = int(input('enter an integer: '))
    a1 = range(1, N+1)
    for n in a1:
        if n % 2 == 0:
            print(n**2)

# %%
even_squared()
# Out:
# enter an integer: 10
# 4
# 16
# 36
# 64
# 100

# %% [markdown]
# #### 2) Using a while loop and the **input()** function, read an indefinite amount of **integers** until the number read is **-1**. After this process, print two lists on the screen: The first containing the even integers, and the second containing the odd integers. Both must be in ascending order.

# %%
def a_function():
    list1 = []
    list2 = []
    list3 = []
    while True:
        x = int(input())
        if x == -1:
            break
        list1.append(x)
    for x in list1:
        if x % 2 == 0:
            list2.append(x)
        else:
            list3.append(x)
    print("List of even integers: ", list2)
    print("List of odd integers: ", list3)

# %%
a_function()
# Out:
# 2
# 3
# 4
# 5
# 6
# -1
# List of even integers:  [2, 4, 6]
# List of odd integers:  [3, 5]

# %% [markdown]
# #### 3) Create a function called **"even_account"** that receives a list of integers, counts the number of existing even elements, and returns this count.

# %%
def even_account():
    list4 = []
    list5 = []
    x = input()
    integers = x.split()
    for n in integers:
        list4.append(int(n))
    for n in list4:
        if n % 2 == 0:
            list5.append(int(n))
    print("count of even elements in list of integers: ", len(list5))

# %%
even_account()
# Out:
# 2 3 4 5 6 7
# count of even elements in list of integers:  3

# %% [markdown]
# #### 4) Create a function called **"squared_list"** that receives a list of integers and returns another list whose elements are the squares of the elements of the first.

# %%
def squared_list():
    list6 = []
    x = input()
    integers = x.split()
    for n in integers:
        list6.append(int(n)**2)
    print("squares of the input: ", list6)

# %%
squared_list()
# Out:
# 2 3 4 5 6
# squares of the input:  [4, 9, 16, 25, 36]

# %% [markdown]
# #### 5) Create a function called **"descending"** that receives two lists of integers and returns a single list, which contains all the elements in descending order, and may include repeated elements.

# %%
def descending():
    list7 = []
    list8 = []
    list9 = []
    x7 = input("elements of a list: ")
    integers7 = x7.split()
    for n in integers7:
        int(n)
        list7.append(int(n))
    x8 = input("Elements of a second list: ")
    integers8 = x8.split()
    for n in integers8:
        int(n)
        list8.append(int(n))
    list9 = list7 + list8
    list9.sort(reverse=True)
    print("this is the list in descending order: ", list9)

# %%
descending()
# Out:
# elements of a list: 2 3 44 54 56 67
# Elements of a second list: 56 67 87 99 65
# this is the list in descending order:  [99, 87, 67, 67, 65, 56, 56, 54, 44, 3, 2]

# %% [markdown]
# #### 6) Create a function called **"adding"** that receives a list **A**, and an arbitrary number of integers as input. Return a new list containing the elements of **A** plus the integers passed as input, in the order in which they were given. Here is an example:
#
# >```python
# >>>> A = [10,20,30]
# >>>> adding(A, 4, 10, 50, 1)
# > [10, 20, 30, 4, 10, 50, 1]
# ```

# %%
def adding(*args):
    A = [10,20,30]
    A.extend(args)
    print(A)

# %%
adding(3, 4, 5, 66, 7)
# Out:
# [10, 20, 30, 3, 4, 5, 66, 7]

# %% [markdown]
# #### 7) Create a function called **"intersection"** that receives two input lists and returns another list with the values that belong to the two lists simultaneously (intersection) without repetition of values and in ascending order. Use only lists (do not use sets); loops and conditionals. See the example:
#
# >```python
# >>>> A = [-2, 0, 1, 2, 3]
# >>>> B = [-1, 2, 3, 6, 8]
# >>>> intersection(A,B)
# > [2, 3]
# ```

# %%
def intersection():
    A = []
    B = []
    x = input("elements of a list: ")
    x1 = x.split()
    for n in x1:
        int(n)
        A.append(int(n))
    y = input("Elements of a second list: ")
    y1 = y.split()
    for n in y1:
        int(n)
        B.append(int(n))
    intersection = list(set(A).intersection(set(B)))
    print(intersection)

# %%
intersection()
# Out:
# elements of a list: 2 3 44 5 6 78
# Elements of a second list: 5 6 77 8 89 4 3 2
# [2, 3, 5, 6]

# %% [markdown]
# #### 8) Create a function called **"union"** that receives two input lists and returns another list with the union of the elements of the two received, without repetition of elements and in ascending order. Use only lists (do not use sets); loops and conditionals. See the example:
#
# >```python
# >>>> A = [-2, 0, 1, 2]
# >>>> B = [-1, 1, 2, 10]
# >>>> union(A,B)
# > [-2, ,-1, 0, 1, 2, 10]
# ```

# %%
def union(A, B):
    A = []
    B = []
    x = input("elements of a list: ")
    x1 = x.split()
    for n in x1:
        int(n)
        A.append(int(n))
    y = input("Elements of a second list: ")
    y1 = y.split()
    for n in y1:
        int(n)
        B.append(int(n))
    C = list(set(A) | set(B))
    print(C)

# %%
union(A,B)
# Out:
# elements of a list: 2 3 4 55 6 77 8 9
# Elements of a second list: 3 4 55 6 7 77 8 9 12 13 24
# [2, 3, 4, 6, 7, 8, 9, 12, 77, 13, 24, 55]

# %% [markdown]
# #### 9) Generalize the **"intersection"** function so that it receives an indefinite number of lists and returns the intersection of all of them. Call the new function **intersection2**.

# %% [markdown]
# ## Challenge
#
# #### 10) Create a function named **"matrix"** that implements matrix multiplication:
#
# Given the matrices:
#
# $A_{m\times n}=
# \left[\begin{matrix}
# a_{11}&a_{12}&...&a_{1n}\\
# a_{21}&a_{22}&...&a_{2n}\\
# \vdots &\vdots &&\vdots\\
# a_{m1}&a_{m2}&...&a_{mn}\\
# \end{matrix}\right]$
#
# We will represent then as a list of lists.
#
# $A = [[a_{11},a_{12},...,a_{1n}],[a_{21},a_{22},...,a_{2n}], . . . ,[a_{m1},a_{m2},...,a_{mn}]]$
#
# The **"matrix"** funtion must receive two matrices $A$ e $B$ in the specified format and return $A\times B$
